# %% [markdown]
# # UN Data API Exercise

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Use the API to get all available data for the GDP per capita, PPP (constant 2017 international $) indicator. Hint: this indicator has code "NY.GDP.PCAP.PP.KD". Adjust the query parameters so that you can retrieve all available rows. Convert the results to a DataFrame.
#
# 2. Now, use the API to get all available data for Life expectancy at birth, total (years). This indicator has code "SP.DYN.LE00.IN". Again, convert the results to a DataFrame.

# %%
# Define the base URL for the World Bank API
base_url = 'https://api.worldbank.org/v2/country/all/indicator/'

# Define multiple indicators
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
indicators = {
    'GDP_per_capita': gdp_per_capita_indicator,
    'Life_expectancy_at_birth': life_expectancy_at_birth_indicator
}

format_type = 'json'
params = {
    'format': format_type,
    'per_page': 20000  # High number to get all rows in one request
}

# Initialize an empty list to store DataFrames
worlddata_dfs = []

# Loop through each indicator and fetch data
for indicator_name, indicator_code in indicators.items():
    # Fetch the data from the World Bank API for the current indicator
    response = requests.get(f"{base_url}{indicator_code}", params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        
        # Check if the response contains data
        if len(data) > 1:
            # Convert the data into a pandas DataFrame
            indicator_df = pd.DataFrame(data[1])
            
            # Add a column to indicate which indicator the data belongs to
            indicator_df['Indicator'] = indicator_name
            
            # Append this DataFrame to the list
            worlddata_dfs.append(indicator_df)
        else:
            print(f"No data found for the {indicator_name} indicator.")
    else:
        print(f"Failed to retrieve data for {indicator_name}. Status code: {response.status_code}")
worldbank_gdp_df = worlddata_dfs[0]
worldbank_le_df = worlddata_dfs[1]

# %%
worldbank_gdp_df
# Out:
#                                                indicator  \
# 0      {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 1      {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 2      {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 3      {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 4      {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# ...                                                  ...
# 17019  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 17020  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 17021  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 17022  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 17023  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 17019                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17020                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17021                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17022                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17023                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date        value unit obs_status  decimal       Indicator
# 0      2023  4047.007031                        0  GDP_per_capita
# 1      2022  4038.638689                        0  GDP_per_capita
# 2      2021  3994.171654                        0  GDP_per_capita
# 3      2020  3919.499230                        0  GDP_per_capita
# 4      2019  4130.057222                        0  GDP_per_capita
# ...     ...          ...  ...        ...      ...             ...
# 17019  1964          NaN                        0  GDP_per_capita
# 17020  1963          NaN                        0  GDP_per_capita
# 17021  1962          NaN                        0  GDP_per_capita
# 17022  1961          NaN                        0  GDP_per_capita
# 17023  1960          NaN                        0  GDP_per_capita
#
# [17024 rows x 9 columns]

# %%
worldbank_le_df
# Out:
#                                                indicator  \
# 0      {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 1      {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 2      {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 3      {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 4      {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# ...                                                  ...
# 17019  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 17020  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 17021  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 17022  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 17023  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 17019                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17020                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17021                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17022                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 17023                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date      value unit obs_status  decimal                 Indicator
# 0      2023        NaN                        0  Life_expectancy_at_birth
# 1      2022  62.899031                        0  Life_expectancy_at_birth
# 2      2021  62.454590                        0  Life_expectancy_at_birth
# 3      2020  63.313860                        0  Life_expectancy_at_birth
# 4      2019  63.755678                        0  Life_expectancy_at_birth
# ...     ...        ...  ...        ...      ...                       ...
# 17019  1964  54.994000                        0  Life_expectancy_at_birth
# 17020  1963  54.549000                        0  Life_expectancy_at_birth
# 17021  1962  54.071000                        0  Life_expectancy_at_birth
# 17022  1961  53.619000                        0  Life_expectancy_at_birth
# 17023  1960  53.235000                        0  Life_expectancy_at_birth
#
# [17024 rows x 9 columns]

# %% [markdown]
# Explode country column so we get country names for gdp dataframe. Then concatenate with gdp data frame. Finally, isolate the year 2021.

# %%
country_exploded = (
    pd.json_normalize(worldbank_gdp_df['country'])
    .rename(columns={'value':'Country'})
    .drop(columns=['id'])
)
worldbank_country_exp_df = (pd.concat([worldbank_gdp_df.drop(columns=['country']), country_exploded], axis=1)
                            .drop(columns=['countryiso3code','unit','obs_status','decimal','Indicator','indicator'])
                            .rename(columns={'value':'GDP_Per_Capita','date':'Year'})
)
worldbank_country_exp_df['Year'] = worldbank_country_exp_df['Year'].astype('int16')
worldbank_country_exp_df_2021 = worldbank_country_exp_df[worldbank_country_exp_df['Year']==2021]
worldbank_country_exp_df_2021
# Out:
#        Year  GDP_Per_Capita                         Country
# 2      2021     3994.171654     Africa Eastern and Southern
# 66     2021     4756.308419      Africa Western and Central
# 130    2021    15776.984852                      Arab World
# 194    2021    19757.122425          Caribbean small states
# 258    2021    39902.215832  Central Europe and the Baltics
# ...     ...             ...                             ...
# 16706  2021    46238.059654           Virgin Islands (U.S.)
# 16770  2021     5663.121607              West Bank and Gaza
# 16834  2021             NaN                     Yemen, Rep.
# 16898  2021     3526.507418                          Zambia
# 16962  2021     3276.267753                        Zimbabwe
#
# [266 rows x 3 columns]

# %% [markdown]
# Explode country column so we get country names for le dataframe. Then concatenate with le data frame. Finally, isolate the year 2021.

# %%
country_exploded = (
    pd.json_normalize(worldbank_le_df['country'])
    .rename(columns={'value':'Country'})
    .drop(columns=['id'])
)
worldbank_country_exp_le_df = (pd.concat([worldbank_le_df.drop(columns=['country']), country_exploded], axis=1)
                            .drop(columns=['countryiso3code','unit','obs_status','decimal','Indicator','indicator'])
                            .rename(columns={'value':'Life_Expectancy_at_Birth','date':'Year'})
)
worldbank_country_exp_le_df['Year'] = worldbank_country_exp_le_df['Year'].astype('int16')
worldbank_country_exp_le_df_2021 = worldbank_country_exp_le_df[worldbank_country_exp_le_df['Year']==2021] #getting all data for 2021
worldbank_country_exp_le_df_2021
# Out:
#        Year  Life_Expectancy_at_Birth                         Country
# 2      2021                 62.454590     Africa Eastern and Southern
# 66     2021                 56.988657      Africa Western and Central
# 130    2021                 70.814483                      Arab World
# 194    2021                 70.481791          Caribbean small states
# 258    2021                 74.797401  Central Europe and the Baltics
# ...     ...                       ...                             ...
# 16706  2021                 80.068293           Virgin Islands (U.S.)
# 16770  2021                 73.473000              West Bank and Gaza
# 16834  2021                 63.753000                     Yemen, Rep.
# 16898  2021                 61.223000                          Zambia
# 16962  2021                 59.253000                        Zimbabwe
#
# [266 rows x 3 columns]

# %% [markdown]
# 3. Merge the two results DataFrames together. You may want to rename or drop columns prior to merging.

# %%
worldbank_gdp_le_2021 = pd.merge(worldbank_country_exp_df_2021, worldbank_country_exp_le_df_2021, how='outer')
worldbank_gdp_le_2021 = worldbank_gdp_le_2021[['Country','Year','GDP_Per_Capita','Life_Expectancy_at_Birth']]
worldbank_gdp_le_2021
# Out:
#                          Country  Year  GDP_Per_Capita  \
# 0                    Afghanistan  2021     2138.870247
# 1    Africa Eastern and Southern  2021     3994.171654
# 2     Africa Western and Central  2021     4756.308419
# 3                        Albania  2021    16261.804554
# 4                        Algeria  2021    14690.916230
# ..                           ...   ...             ...
# 261           West Bank and Gaza  2021     5663.121607
# 262                        World  2021    19724.129207
# 263                  Yemen, Rep.  2021             NaN
# 264                       Zambia  2021     3526.507418
# 265                     Zimbabwe  2021     3276.267753
#
#      Life_Expectancy_at_Birth
# 0                   61.982000
# 1                   62.454590
# 2                   56.988657
# 3                   76.463000
# 4                   76.377000
# ..                        ...
# 261                 73.473000
# 262                 71.327157
# 263                 63.753000
# 264                 61.223000
# 265                 59.253000
#
# [266 rows x 4 columns]

# %% [markdown]
# 4. You can also get more information about the available countries (region, capital city, income level classification, etc.) by using the Country API. Use this API to pull in all available data. Merge this with your other datasets. Use this to now remove the rows that correspond to regions and not countries.

# %%
url = 'https://api.worldbank.org/v2/country/'
format_type = 'json'
params = {
    'format': format_type,
    'per_page': 10000  # High number to get all rows in one request
}
response = requests.get(url,params=params)    # Check if the request was successful
if response.status_code == 200:
    data = response.json()
        
    # Check if the response contains data
    if len(data) > 1:
        # Convert the data into a pandas DataFrame
        country_df = pd.DataFrame(data[1])
    else:
        print(f'No data could be found for {url}')
else:
    print(f"Failed to retrieve data for {url}. Status code: {response.status_code}")
country_df = (
    country_df.replace('', np.nan)
    .dropna(subset='capitalCity')
    .drop(columns=['region', 'adminregion', 'incomeLevel' ,'lendingType'])
    .rename(columns={'name':'Country', 'capitalCity':'Capital_City'})
)
country_df #should only have regions with capital cities, i.e. countries
# Out:
#       id iso2Code       Country      Capital_City longitude  latitude
# 0    ABW       AW         Aruba        Oranjestad  -70.0167   12.5167
# 2    AFG       AF   Afghanistan             Kabul   69.1761   34.5228
# 5    AGO       AO        Angola            Luanda    13.242  -8.81155
# 6    ALB       AL       Albania            Tirane   19.8172   41.3317
# 7    AND       AD       Andorra  Andorra la Vella    1.5218   42.5075
# ..   ...      ...           ...               ...       ...       ...
# 290  XKX       XK        Kosovo          Pristina    20.926    42.565
# 292  YEM       YE   Yemen, Rep.            Sana'a   44.2075    15.352
# 293  ZAF       ZA  South Africa          Pretoria   28.1871   -25.746
# 294  ZMB       ZM        Zambia            Lusaka   28.2937  -15.3982
# 295  ZWE       ZW      Zimbabwe            Harare   31.0672  -17.8312
#
# [211 rows x 6 columns]

# %%
countries_gdp_le_2021 = pd.merge(country_df, worldbank_gdp_le_2021, how='left')
countries_gdp_le_2021
# Out:
#       id iso2Code       Country      Capital_City longitude  latitude  Year  \
# 0    ABW       AW         Aruba        Oranjestad  -70.0167   12.5167  2021
# 1    AFG       AF   Afghanistan             Kabul   69.1761   34.5228  2021
# 2    AGO       AO        Angola            Luanda    13.242  -8.81155  2021
# 3    ALB       AL       Albania            Tirane   19.8172   41.3317  2021
# 4    AND       AD       Andorra  Andorra la Vella    1.5218   42.5075  2021
# ..   ...      ...           ...               ...       ...       ...   ...
# 206  XKX       XK        Kosovo          Pristina    20.926    42.565  2021
# 207  YEM       YE   Yemen, Rep.            Sana'a   44.2075    15.352  2021
# 208  ZAF       ZA  South Africa          Pretoria   28.1871   -25.746  2021
# 209  ZMB       ZM        Zambia            Lusaka   28.2937  -15.3982  2021
# 210  ZWE       ZW      Zimbabwe            Harare   31.0672  -17.8312  2021
#
#      GDP_Per_Capita  Life_Expectancy_at_Birth
# 0      38226.146157                    74.626
# 1       2138.870247                    61.982
# 2       7414.278958                    61.643
# 3      16261.804554                    76.463
# 4      58829.850072                       NaN
# ..              ...                       ...
# 206    12362.704808                    76.806
# 207             NaN                    63.753
# 208    14172.544251                    62.341
# 209     3526.507418                    61.223
# 210     3276.267753                    59.253
#
# [211 rows x 9 columns]

# %% [markdown]
# ## Bonus Questions

# %% [markdown]
# Adjust your request so that it returns data just for the United States.

# %%
usa_url = 'https://api.worldbank.org/v2/country/usa/indicator/'
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
indicator_list = [gdp_per_capita_indicator, life_expectancy_at_birth_indicator]
format_type = 'json'
params = {
    'format': format_type,
    'per_page': 10000  # High number to get all rows in one request
}
request_str = usa_url
for indicator in indicator_list:
    if indicator_list.index(indicator) != len(indicator_list)-1:
        request_str = request_str + indicator + ';'
    else:
        request_str = request_str + indicator + '?source=' + str(len(indicator_list))
response = requests.get(request_str, params=params)
data = response.json()
data[1]
# Out:
# [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2023',
#   'value': 73637.3027885905,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2022',
#   'value': 72165.4834696586,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 71055.87619383,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 67266.187874108,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 69458.6101827166,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 68095.6868059923,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 66482.8934392041,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 65299.9993837591,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 64599.5737360527,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 63214.8953462352,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 62112.583447369,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 61247.3170720931,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 60317.5425206572,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 59821.6650811366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 58736.9461328153,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 60821.1859611643,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 61329.5392265213,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 60699.2720850035,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 59627.0590559421,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 58153.3878283911,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 56519.3507123652,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 55456.8624028822,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 55037.8936729664,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 55059.2191687802,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1999',
#   'value': 53494.0566028874,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1998',
#   'value': 51639.1871337683,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1997',
#   'value': 50002.9748720618,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1996',
#   'value': 48453.8258145334,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1995',
#   'value': 47238.6290898533,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1994',
#   'value': 46554.7724569344,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1993',
#   'value': 45303.8828831126,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1992',
#   'value': 44675.8639074727,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1991',
#   'value': 43758.395353687,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1990',
#   'value': 44395.1314543953,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1989',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1988',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1987',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1986',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1985',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1984',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1983',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1982',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1981',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1980',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1979',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1978',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1977',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1976',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1975',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1974',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1973',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1972',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1971',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1970',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1969',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1968',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1967',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1966',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1965',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1964',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1963',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1962',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1961',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1960',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2023',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2022',
#   'value': 77.4341463414634,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 76.3292682926829,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 76.9804878048781,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 78.7878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 78.6390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 78.690243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 78.8414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 78.6414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 78.5414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 78.390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 78.0390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 77.9878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 77.6878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 77.0365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 76.9365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 76.8365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 76.6365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1999',
#   'value': 76.5829268292683,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1998',
#   'value': 76.5804878048781,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1997',
#   'value': 76.4292682926829,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1996',
#   'value': 76.0268292682927,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1995',
#   'value': 75.6219512195122,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1994',
#   'value': 75.619512195122,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1993',
#   'value': 75.419512195122,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1992',
#   'value': 75.6170731707317,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1991',
#   'value': 75.3658536585366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1990',
#   'value': 75.2146341463415,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1989',
#   'value': 75.0170731707317,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1988',
#   'value': 74.7658536585366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1987',
#   'value': 74.7658536585366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1986',
#   'value': 74.6146341463415,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1985',
#   'value': 74.5634146341464,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1984',
#   'value': 74.5634146341464,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1983',
#   'value': 74.4634146341463,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1982',
#   'value': 74.3609756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1981',
#   'value': 74.009756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1980',
#   'value': 73.609756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1979',
#   'value': 73.8048780487805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1978',
#   'value': 73.3560975609756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1977',
#   'value': 73.2560975609756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1976',
#   'value': 72.8560975609756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1975',
#   'value': 72.6048780487805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1974',
#   'value': 71.9560975609756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1973',
#   'value': 71.3560975609756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1972',
#   'value': 71.1560975609756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1971',
#   'value': 71.1073170731707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1970',
#   'value': 70.8073170731707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1969',
#   'value': 70.5073170731708,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1968',
#   'value': 69.9512195121951,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1967',
#   'value': 70.5609756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1966',
#   'value': 70.2121951219512,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1965',
#   'value': 70.2146341463415,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1964',
#   'value': 70.1658536585366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1963',
#   'value': 69.9170731707317,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1962',
#   'value': 70.119512195122,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1961',
#   'value': 70.2707317073171,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1960',
#   'value': 69.7707317073171,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %% [markdown]
# 2. Adjust your request so that it returns data just for the United States for the year 2021.

# %%
usa_url = 'https://api.worldbank.org/v2/country/usa/indicator/'
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
indicator_list = [gdp_per_capita_indicator, life_expectancy_at_birth_indicator]
date = 2020
format_type = 'json'
params = {
    'format': format_type,
    'per_page': 10000  # High number to get all rows in one request
}
request_str = usa_url
for indicator in indicator_list:
    if indicator_list.index(indicator) != len(indicator_list)-1:
        request_str = request_str + indicator + ';'
    else:
        request_str = request_str + indicator + '?source=' + str(len(indicator_list))
response = requests.get(request_str+'&date='+str(date), params=params)
data = response.json()
data[1]
# Out:
# [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 67266.187874108,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 76.9804878048781,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %% [markdown]
# 3. Adjust your request so that it returns data just for the United States for the years 2000 through 2021.

# %%
usa_url = 'https://api.worldbank.org/v2/country/usa/indicator/'
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
indicator_list = [gdp_per_capita_indicator, life_expectancy_at_birth_indicator]
date_range = '2000:2021'
format_type = 'json'
params = {
    'format': format_type,
    'per_page': 10000  # High number to get all rows in one request
}
request_str = usa_url
for indicator in indicator_list:
    if indicator_list.index(indicator) != len(indicator_list)-1:
        request_str = request_str + indicator + ';'
    else:
        request_str = request_str + indicator + '?source=' + str(len(indicator_list))
response = requests.get(request_str+'&date='+date_range, params=params)
data = response.json()
data[1]
# Out:
# [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 71055.87619383,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 67266.187874108,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 69458.6101827166,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 68095.6868059923,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 66482.8934392041,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 65299.9993837591,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 64599.5737360527,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 63214.8953462352,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 62112.583447369,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 61247.3170720931,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 60317.5425206572,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 59821.6650811366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 58736.9461328153,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 60821.1859611643,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 61329.5392265213,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 60699.2720850035,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 59627.0590559421,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 58153.3878283911,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 56519.3507123652,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 55456.8624028822,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 55037.8936729664,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 55059.2191687802,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 76.3292682926829,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 76.9804878048781,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 78.7878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 78.6390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 78.690243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 78.8414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 78.6414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 78.5414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 78.390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 78.0390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 77.9878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 77.6878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 77.0365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 76.9365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 76.8365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 76.6365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %% [markdown]
# 4. Adjust your request so that it returns data for the United States and Canada for the years 2000 through 2021.

# %%
countries_url = 'https://api.worldbank.org/v2/country/usa;can/indicator/'
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
indicator_list = [gdp_per_capita_indicator, life_expectancy_at_birth_indicator]
date_range = '2000:2021'
format_type = 'json'
params = {
    'format': format_type,
    'per_page': 10000  # High number to get all rows in one request
}
request_str = countries_url
for indicator in indicator_list:
    if indicator_list.index(indicator) != len(indicator_list)-1:
        request_str = request_str + indicator + ';'
    else:
        request_str = request_str + indicator + '?source=' + str(len(indicator_list))
response = requests.get(request_str+'&date='+date_range, params=params)
data = response.json()
data[1]
# Out:
# [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2021',
#   'value': 55781.6990272912,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2020',
#   'value': 53274.9109302286,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2019',
#   'value': 56713.0888767094,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2018',
#   'value': 56470.4592673931,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2017',
#   'value': 55756.2624817832,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2016',
#   'value': 54765.3037720868,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2015',
#   'value': 54819.1890353874,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2014',
#   'value': 54880.8582018562,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2013',
#   'value': 53884.8455875649,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2012',
#   'value': 53217.7135831819,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2011',
#   'value': 52869.3878559359,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2010',
#   'value': 51763.6758102969,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2009',
#   'value': 50772.8699217538,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2008',
#   'value': 52899.4754504882,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2007',
#   'value': 52948.8994271698,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2006',
#   'value': 52391.3792619498,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2005',
#   'value': 51564.8455651212,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2004',
#   'value': 50436.294842704,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2003',
#   'value': 49381.5950355437,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2002',
#   'value': 48943.5412414992,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2001',
#   'value': 48036.6266178082,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2000',
#   'value': 47667.4330856329,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 71055.87619383,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 67266.187874108,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 69458.6101827166,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 68095.6868059923,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 66482.8934392041,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 65299.9993837591,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 64599.5737360527,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 63214.8953462352,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 62112.583447369,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 61247.3170720931,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 60317.5425206572,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 59821.6650811366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 58736.9461328153,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 60821.1859611643,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 61329.5392265213,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 60699.2720850035,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 59627.0590559421,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 58153.3878283911,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 56519.3507123652,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 55456.8624028822,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 55037.8936729664,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 55059.2191687802,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2021',
#   'value': 81.5870731707317,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2020',
#   'value': 81.6604878048781,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2019',
#   'value': 82.2239024390244,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2018',
#   'value': 81.8439024390244,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2017',
#   'value': 81.8329268292683,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2016',
#   'value': 81.9248780487805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2015',
#   'value': 81.8156097560976,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2014',
#   'value': 81.7843902439025,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2013',
#   'value': 81.7448780487805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2012',
#   'value': 81.6636585365854,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2011',
#   'value': 81.4826829268293,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2010',
#   'value': 81.3221951219512,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2009',
#   'value': 81.0660975609756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2008',
#   'value': 80.7246341463415,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2007',
#   'value': 80.5436585365854,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2006',
#   'value': 80.5436585365854,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2005',
#   'value': 80.1126829268293,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2004',
#   'value': 79.9921951219512,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2003',
#   'value': 79.7151219512195,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2002',
#   'value': 79.5307317073171,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2001',
#   'value': 79.3980487804878,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2000',
#   'value': 79.1668292682927,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 76.3292682926829,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 76.9804878048781,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 78.7878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 78.6390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 78.690243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 78.8414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 78.6414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 78.5414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 78.390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 78.0390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 77.9878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 77.6878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 77.0365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 76.9365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 76.8365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 76.6365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %% [markdown]
# Let's try to generalize with a function. We will begin by creating a dictionary with countries and their ids as key value pairs.

# %%
gdp_le = pd.merge(worldbank_country_exp_df, worldbank_country_exp_le_df)
gdp_le_country = pd.merge(gdp_le, country_df, how='right')
country_id_dict = gdp_le_country.set_index('Country')['id'].to_dict()

# %% [markdown]
# worldbank_api_query is a way to request info from the worldbank api. It incorporates an initial request with a 'per_page' parameter of 1, discovers the total number of pages possible, and then adjusts the parameter accordingly. *Note: for some reason, I am having trouble utilyzing indicator IDs other than GDP Per Capita and Life Expectancy in this function.

# %%
import json
import difflib  #Importing the difflib module for string matching

def find_closest_dict_match(country, country_id_dict):
    #Find the closest match for a given country name in the country_id_dict.
    keys = list(country_id_dict.keys())
    closest_matches = difflib.get_close_matches(country, keys, n=1, cutoff=0.8)  # Adjust cutoff for match sensitivity
    return closest_matches[0] if closest_matches else None

def worldbank_api_query(countries=None,  # takes a list of country names
                        indicators=None,  # list of indicators
                        date=None, date_range_begin=None, date_range_end=None,
                        format_type='json'):
    init_request = True
    base_url = 'https://api.worldbank.org/v2/'
    init_params = {
        'format': format_type,
        'per_page': 1
    }
    
    # Check if countries are valid
    if countries:
        country_ids = []
        for country in countries:
            if country in country_id_dict:  # Check if country exists in country_id_dict
                country_ids.append(country_id_dict[country])
            else:
                # Suggest closest match
                closest_match = find_closest_dict_match(country, country_id_dict)
                if closest_match:
                    print(f"Warning: '{country}' not found. Did you mean '{closest_match}'?")
                    country_ids.append(country_id_dict[closest_match])  # Append the closest match ID
                else:
                    print(f"Error: '{country}' not found and no suggestions available.")
                    return None
                
        country_ids_str = ';'.join(country_ids)
        url = f'{base_url}country/{country_ids_str}/'
    else:
        url = f'{base_url}country/all'

    #indicators parameter
    if indicators:
        if len(indicators)>1:
            indicators_str = ';'.join(indicators)
            url = f'{url}indicator/{indicators_str}?source={len(indicators)}'
        else:
            url = f'{url}indicator/{indicators[0]}?'
    else:
        raise ValueError('indicators parameter cannot be None')

    #date parameter
    if date is not None and (date_range_begin is None or date_range_end is None):
        date_param = date
    elif date_range_begin is not None and date_range_end is not None:
        date_param = f"{date_range_begin}:{date_range_end}"
    else:
        date_param = None
    # Add date parameter to URL if it exists
    if date_param is not None:
        prefix = '&' if len(indicators) > 1 else ''
        url = f"{url}{prefix}date={date_param}"

    print(url)
    
    if init_request:
        response = requests.get(url, params=init_params)
        data = response.json()
        new_params = {
        'format': format_type,
        'per_page': data[0]['total']
        }
        init_request = False
    if not init_request:
        response = requests.get(url, params=new_params)
        # Check if the request was successful
        if response.status_code != 200:
            print(f"Error: Received status code {response.status_code}. Response: {response.text}")
            return None
        
        # Decode the response text to handle BOM and load JSON
        try:
            data = response.content.decode('utf-8-sig')  # Handle BOM
            return json.loads(data)  # Parse JSON using the json module
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e}. Response: {data}")  # Print the raw response data
            return None

countries = ['United States', 'Netherlands']
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
indicator_list = [gdp_per_capita_indicator, life_expectancy_at_birth_indicator]
date_range_begin = 2000
date_range_end = 2021
data = worldbank_api_query(countries=countries, indicators=indicator_list, 
                           date_range_begin=date_range_begin, 
                           date_range_end=date_range_end)
data[1]
# Out:
# https://api.worldbank.org/v2/country/USA;NLD/indicator/NY.GDP.PCAP.PP.KD;SP.DYN.LE00.IN?source=2&date=2000:2021
# [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2021',
#   'value': 67693.3264311302,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2020',
#   'value': 64080.8302893499,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2019',
#   'value': 67043.1699696165,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2018',
#   'value': 66189.4000984502,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2017',
#   'value': 65041.4591487786,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2016',
#   'value': 63576.4761161142,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2015',
#   'value': 62544.9131401361,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2014',
#   'value': 61615.5860911043,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2013',
#   'value': 60969.8536068274,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2012',
#   'value': 61229.576424159,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2011',
#   'value': 62096.3919664397,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2010',
#   'value': 61433.7501674102,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2009',
#   'value': 60931.5161421361,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2008',
#   'value': 63576.9787000631,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2007',
#   'value': 62469.1773802029,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2006',
#   'value': 60329.08775557,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2005',
#   'value': 58404.682754386,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2004',
#   'value': 57364.8309272554,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2003',
#   'value': 56444.1211566052,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2002',
#   'value': 56622.9306158521,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2001',
#   'value': 56861.9599517874,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2000',
#   'value': 55989.9400783388,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 71055.87619383,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 67266.187874108,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 69458.6101827166,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 68095.6868059923,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 66482.8934392041,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 65299.9993837591,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 64599.5737360527,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 63214.8953462352,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 62112.583447369,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 61247.3170720931,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 60317.5425206572,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 59821.6650811366,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 58736.9461328153,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 60821.1859611643,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 61329.5392265213,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 60699.2720850035,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 59627.0590559421,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 58153.3878283911,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 56519.3507123652,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 55456.8624028822,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 55037.8936729664,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2021 international $)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 55059.2191687802,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2021',
#   'value': 81.309756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2020',
#   'value': 81.3585365853659,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2019',
#   'value': 82.1121951219512,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2018',
#   'value': 81.8121951219512,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2017',
#   'value': 81.7609756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2016',
#   'value': 81.5609756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2015',
#   'value': 81.509756097561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2014',
#   'value': 81.7073170731707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2013',
#   'value': 81.3048780487805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2012',
#   'value': 81.1048780487805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2011',
#   'value': 81.2048780487805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2010',
#   'value': 80.7024390243902,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2009',
#   'value': 80.5487804878049,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2008',
#   'value': 80.2512195121951,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2007',
#   'value': 80.0975609756098,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2006',
#   'value': 79.6975609756098,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2005',
#   'value': 79.3463414634146,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2004',
#   'value': 79.0951219512195,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2003',
#   'value': 78.4926829268293,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2002',
#   'value': 78.2926829268293,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2001',
#   'value': 78.190243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'NL', 'value': 'Netherlands'},
#   'countryiso3code': 'NLD',
#   'date': '2000',
#   'value': 77.9878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 76.3292682926829,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 76.9804878048781,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': 78.7878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 78.6390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 78.5390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 78.690243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 78.8414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 78.7414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 78.6414634146341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 78.5414634146342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 78.390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 78.0390243902439,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 77.9878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 77.6878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 77.4878048780488,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 77.0365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 76.9365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 76.8365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 76.6365853658537,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %% [markdown]
# Turns api request into a data frame, all cleaned up!

# %%
def turn_query_into_df(data):
    query_df = pd.DataFrame(data[1])
    query_country_exploded = (
        pd.json_normalize(query_df['country'])
        .rename(columns={'value':'Country'})
        .drop(columns=['id'])
    )
    explode_indicator = (
        pd.json_normalize(query_df['indicator'])
        .drop(columns=['id'])
        .rename(columns={'value':'DataKind'})
    )
    query_df = (
        pd.concat([query_country_exploded, explode_indicator, 
                    query_df.drop(columns=['indicator', 'country'])], axis=1)
        .groupby(['Country','date','DataKind'])['value'].first().unstack(fill_value=0).reset_index()
        .rename(columns={'DataKind':'index'})
    )
    return query_df

# %%
countries = ['United States', 'Netherlands', 'Guinea', 'Luxembourg']
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
indicator_list = [gdp_per_capita_indicator, life_expectancy_at_birth_indicator]
date_range_begin = 1990
date_range_end = 2021
turn_query_into_df(worldbank_api_query(countries=countries, indicators=indicator_list, 
                           date_range_begin=date_range_begin, 
                           date_range_end=date_range_end))
# Out:
# https://api.worldbank.org/v2/country/USA;NLD;GIN;LUX/indicator/NY.GDP.PCAP.PP.KD;SP.DYN.LE00.IN?source=2&date=1990:2021
# DataKind        Country  date  \
# 0                Guinea  1990
# 1                Guinea  1991
# 2                Guinea  1992
# 3                Guinea  1993
# 4                Guinea  1994
# ..                  ...   ...
# 123       United States  2017
# 124       United States  2018
# 125       United States  2019
# 126       United States  2020
# 127       United States  2021
#
# DataKind  GDP per capita, PPP (constant 2021 international $)  \
# 0                                               2132.116671
# 1                                               2101.329836
# 2                                               2101.310205
# 3                                               2140.295084
# 4                                               2159.075290
# ..                                                      ...
# 123                                            66482.893439
# 124                                            68095.686806
# 125                                            69458.610183
# 126                                            67266.187874
# 127                                            71055.876194
#
# DataKind  Life expectancy at birth, total (years)
# 0                                       47.004000
# 1                                       47.546000
# 2                                       48.363000
# 3                                       48.962000
# 4                                       49.171000
# ..                                            ...
# 123                                     78.539024
# 124                                     78.639024
# 125                                     78.787805
# 126                                     76.980488
# 127                                     76.329268
#
# [128 rows x 4 columns]

# %% [markdown]
# A way to search for indicator name and will return its id.

# %%
def create_name_index(data_list):
    """Create a dictionary mapping names to their indices for fast lookup."""
    return {item['name']: index for index, item in enumerate(data_list)}

def find_closest_matches(name_index, name_search, n=5):
    """Find the closest matches using the name index dictionary."""
    closest_matches = difflib.get_close_matches(name_search, name_index.keys(), n=n, cutoff=0.4)
    return closest_matches

def find_index_of_name(data_list, name_search):
    name_index = create_name_index(data_list)
    
    # Check for an exact match
    if name_search in name_index:
        return name_index[name_search]
    
    # If there's no exact match, find the closest matches
    closest_matches = find_closest_matches(name_index, name_search, n=5)
    
    if closest_matches:
        print(f"No exact match found for '{name_search}'. Did you mean one of the following? Assuming first one.")
        for match in closest_matches:
            print(f"- {match}")
        return name_index[closest_matches[0]]  # Return the index of the first closest match
    
    print(f"No match found for '{name_search}'.")
    return -1

def find_indicator_id_for_name(data, name):
    index = find_index_of_name(data, name)
    print(data[index])
    return data[index]['id']

print(data[1]) #need to find data[1] which includes 
find_indicator_id_for_name(data[1], 'gross national income')
# Out:
# [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2023', 'value': 73637.3027885905, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2022', 'value': 72165.4834696586, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2021', 'value': 71055.87619383, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2020', 'value': 67266.187874108, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2019', 'value': 69458.6101827166, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2018', 'value': 68095.6868059923, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2017', 'value': 66482.8934392041, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2016', 'value': 65299.9993837591, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2015', 'value': 64599.5737360527, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2014', 'value': 63214.8953462352, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2013', 'value': 62112.583447369, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2012', 'value': 61247.3170720931, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2011', 'value': 60317.5425206572, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2010', 'value': 59821.6650811366, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per capita, PPP (constant 2021 international $)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '20 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 35
#      32     return data[index]['id']
#      34 print(data[1])
# ---> 35 find_indicator_id_for_name(data[1], 'gross national income')
#
# Cell In[134], line 30, in find_indicator_id_for_name(data, name)
#      29 def find_indicator_id_for_name(data, name):
# ---> 30     index = find_index_of_name(data, name)
#      31     print(data[index])
#      32     return data[index]['id']
#
# Cell In[134], line 11, in find_index_of_name(data_list, name_search)
#      10 def find_index_of_name(data_list, name_search):
# ---> 11     name_index = create_name_index(data_list)
#      13     # Check for an exact match
#      14     if name_search in name_index:
#
# Cell In[134], line 3, in create_name_index(data_list)
#       1 def create_name_index(data_list):
#       2     """Create a dictionary mapping names to their indices for fast lookup."""
# ----> 3     return {item['name']: index for index, item in enumerate(data_list)}
#
# KeyError: 'name'

# %%
gdp_per_capita_indicator = 'NY.GDP.PCAP.PP.KD'
life_expectancy_at_birth_indicator = 'SP.DYN.LE00.IN'
gni = 'C1.7'
indicator_list = [life_expectancy_at_birth_indicator, gdp_per_capita_indicator]
date_range_begin = 1990
date_range_end = 2021
q = worldbank_api_query(countries=['United States', 'Netherlands', 'Ireland', 'China'], indicators=indicator_list, date_range_begin=date_range_begin, date_range_end=date_range_end)
turn_query_into_df(q)
# Out:
# https://api.worldbank.org/v2/country/USA;NLD;IRL;CHN/indicator/SP.DYN.LE00.IN;NY.GDP.PCAP.PP.KD?source=2&date=1990:2021
# DataKind        Country  date  \
# 0                 China  1990
# 1                 China  1991
# 2                 China  1992
# 3                 China  1993
# 4                 China  1994
# ..                  ...   ...
# 123       United States  2017
# 124       United States  2018
# 125       United States  2019
# 126       United States  2020
# 127       United States  2021
#
# DataKind  GDP per capita, PPP (constant 2021 international $)  \
# 0                                               1645.578944
# 1                                               1773.639411
# 2                                               2001.254274
# 3                                               2253.052020
# 4                                               2518.154888
# ..                                                      ...
# 123                                            66482.893439
# 124                                            68095.686806
# 125                                            69458.610183
# 126                                            67266.187874
# 127                                            71055.876194
#
# DataKind  Life expectancy at birth, total (years)
# 0                                       68.005000
# 1                                       68.169000
# 2                                       68.734000
# 3                                       69.216000
# 4                                       69.520000
# ..                                            ...
# 123                                     78.539024
# 124                                     78.639024
# 125                                     78.787805
# 126                                     76.980488
# 127                                     76.329268
#
# [128 rows x 4 columns]
